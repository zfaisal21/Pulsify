# %%
# import library to display image
from IPython import display

# %% [markdown]
# ### Question from Pulsify part 1

# %%
display.Image("./question 1.png")

# %% [markdown]
# ### Question from Pulsify part 2

# %%
display.Image("./question 2.png")

# %% [markdown]
# ### For SQL assessment, I use MySQL platform. I created 3 tables and make some queries
#
# ##### Insert table profile in mySQL

# %%
display.Image("./table profile.png")

# %% [markdown]
# ##### Insert table action in mySQL

# %%
display.Image("./table action.png")

# %%
##### Insert table profile action in mySQL

# %%
display.Image("./table profile_action.png")

# %% [markdown]
# ##### From table action, get details on action_id and action_type whereas get profile_action_id, profile_id and created_at from table profile_action
#
# ##### Join both table and set limit to get the latest value
#
# ##### Save the query into view(involve)

# %%
display.Image("./limit.png")

# %% [markdown]
# ##### Left join table profile and view involve to get the result.
#
# ##### Order by action time to trace the log activity by latest date(to choose last and second last for action and action_time)

# %%
display.Image("./last output.png")

# %% [markdown]
# ##### The expected output result is different from my output result. But the objective to get the detail is still can get from my output result. Thanks
